# %%
import pandas as pd

# %%
data = pd.read_excel("Seasonally Adjusted.xlsx",sheet_name = "LOWER_MAINLAND")
data
# Out:
#           Date  Composite_HPI_SA  Single_Family_HPI_SA  One_Storey_HPI_SA  \
# 0   2005-01-01             100.0                 100.0              100.0
# 1   2005-02-01             100.4                 100.2              100.6
# 2   2005-03-01             100.8                 100.4              101.0
# 3   2005-04-01             101.1                 100.6              101.3
# 4   2005-05-01             101.5                 100.8              101.7
# ..         ...               ...                   ...                ...
# 224 2023-09-01             345.7                 393.3              390.3
# 225 2023-10-01             344.1                 391.0              388.2
# 226 2023-11-01             342.5                 390.0              384.8
# 227 2023-12-01             339.6                 387.8              383.9
# 228 2024-01-01             335.4                 383.0              382.9
#
#      Two_Storey_HPI_SA  Townhouse_HPI_SA  Apartment_HPI_SA  \
# ...
